# %%
import logging

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torchvision

from cycler import cycler
from PIL import Image
from torchvision import datasets, transforms

logging.getLogger().setLevel(logging.INFO)

# %%
class MLP(nn.Module):
    # layer_sizes[0] is the dimension of the input
    # layer_sizes[-1] is the dimension of the output
    def __init__(self, layer_sizes, final_relu=False):
        super().__init__()
        layer_list = []
        layer_sizes = [int(x) for x in layer_sizes]
        num_layers = len(layer_sizes) - 1
        final_relu_layer = num_layers if final_relu else num_layers - 1
        for i in range(len(layer_sizes) - 1):
            input_size = layer_sizes[i]
            curr_size = layer_sizes[i + 1]
            if i < final_relu_layer:
                layer_list.append(nn.ReLU(inplace=False))
            layer_list.append(nn.Linear(input_size, curr_size))
        self.net = nn.Sequential(*layer_list)
        self.last_linear = self.net[-1]

    def forward(self, x):
        return self.net(x)

# %%
from copy import copy
import os
import re
from torchvision.datasets import CelebA
from torch.utils.data import default_collate

class CelebAPositives(CelebA):
    def __getitem__(self, index: int):
        X = Image.open(os.path.join(self.root, self.base_folder, "img_align_celeba", self.filename[index]))

        target = []
        for t in self.target_type:
            if t == "attr":
                target.append(self.attr[index, :])
            elif t == "identity":
                target.append(self.identity[index, 0])
            elif t == "bbox":
                target.append(self.bbox[index, :])
            elif t == "landmarks":
                target.append(self.landmarks_align[index, :])
            elif 'augmented positives' in t:
                target.append(index)
            else:
                # TODO: refactor with utils.verify_str_arg
                raise ValueError(f'Target type "{t}" is not recognized.')

        if target:
            target = tuple(target) if len(target) > 1 else target[0]

            if self.target_transform is not None:
                target = self.target_transform(target)
        else:
            target = None

        for t in self.target_type:
            if 'augmented positives' in t:
                assert self.transform is not None
                num_augs = re.search('\d+', t)
                assert num_augs
                assert num_augs.group(0)
                num_augs = int(num_augs.group(0))
                X_list = []
                target_list = []
                for _ in range(num_augs):
                    X_list.append(self.transform(X))
                    target_list.append(copy(target))
                return X_list, target_list

        if self.transform is not None:
            X = self.transform(X)
        return [X], [target]

def unwrap_collate(lst):
    return default_collate(sum(lst))

# %%
# !mamba install pytorch-metric-learning -c conda-forge -c pytorch -y
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.25.0) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pytorch-metric-learning']
#
# conda-forge/osx-arm64                                       Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# [+] 0.1s
# pytorch/osx-arm64 ━━━━━━━━━━━━╸━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pytorch/noarch    ━━━━━━━━━━━━━╸━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.2s
# pytorch/osx-arm64 ━━━━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# pytorch/noarch    ━━━━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2spytorch/noarch                                                No change
# [+] 0.3s
# pytorch/osx-arm64 ╸━━━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s[+] 0.4s
# pytorch/osx-arm64 ╸━━━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4s[+] 0.5s
# pytorch/osx-arm64 ╸━━━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.5s[+] 0.6s
# pytorch/osx-arm64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━━  15.0 B /  ??.?MB @  25.0 B/s  0.6spytorch/osx-arm64                                    6.9kB @  11.4kB/s  0.6s
#
# Pinned packages:
#   - python 3.10.*
#
#
# warning  libmamba Extracted package cache '/Users/penchekrak/mambaforge/pkgs/joblib-1.2.0-pyhd8ed1ab_0' has invalid url
# warning  libmamba Extracted package cache '/Users/penchekrak/mambaforge/pkgs/threadpoolctl-3.1.0-pyh8a188c0_0' has invalid url
# Transaction
#
#   Prefix: /Users/penchekrak/mambaforge/envs/TopologicalRegularization
#
#   Updating specs:
#
#    - pytorch-metric-learning
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                    Version  Build            Channel                     Size
# ─────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────────────
#
#   + joblib                     1.2.0  pyhd8ed1ab_0     conda-forge/noarch        Cached
#   + pooch                      1.7.0  pyhd8ed1ab_0     conda-forge/noarch        Cached
#   + pytorch-metric-learning    2.0.1  pyhd8ed1ab_0     conda-forge/noarch          71kB
#   + scikit-learn               1.2.2  py310ha00a7cd_0  conda-forge/osx-arm64        7MB
#   + scipy                     1.10.1  py310ha0d8a01_0  conda-forge/osx-arm64     Cached
#   + threadpoolctl              3.1.0  pyh8a188c0_0     conda-forge/noarch        Cached
#
#   Upgrade:
# ─────────────────────────────────────────────────────────────────────────────────────────
#
#   - openssl                    3.0.8  h03a7124_0       conda-forge
#   + openssl                    3.1.0  h03a7124_0       conda-forge/osx-arm64        2MB
#
#   Summary:
#
#   Install: 6 packages
#   Upgrade: 1 packages
#
#   Total download: 9MB
#
# ─────────────────────────────────────────────────────────────────────────────────────────
#
# [+] 0.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B                            0.0s
# Extracting   (2) ━━━━━━━━╸━━━━━━━━━━━━━━       0 joblib                     0.0s[+] 0.1s
# Downloading  (3) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B openssl                    0.0s
# Extracting       ━━━━━━━━╸━━━━━━━━╸━━━━━       2                            0.1s[+] 0.2s
# Downloading  (3) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B openssl                    0.1s
# Extracting       ━━━━━━━━╸━━━━━━━━╸━━━━━       2                            0.1s[+] 0.3s
# Downloading  (3) ━━━━━━━━━━━━━━━━━━━━━━━  35.5kB openssl                    0.2s
# Extracting       ━━━━━━━━╸━━━━━━━━╸━━━━━       2                            0.1s[+] 0.4s
# Downloading  (3) ━━━━━━━━━━━━━━━━━━━━━━━  35.5kB openssl                    0.3s
# Extracting       ━━━━━━━━╸━━━━━━━━╸━━━━━       2                            0.1s[+] 0.5s
# Downloading  (3) ━━━━━━━━━━━━━━━━━━━━━━━  35.5kB pytorch-metric-learning    0.4s
# Extracting       ━━━━━━━━╸━━━━━━━━╸━━━━━       2                            0.1s[+] 0.6s
# Downloading  (3) ━━━━━━━━━━━━━━━━━━━━━━━  35.5kB pytorch-metric-learning    0.5s
# Extracting       ━━━━━━━━╸━━━━━━━━╸━━━━━       2                            0.1s[+] 0.7s
# Downloading  (3) ━━━━━━━━━━━━━━━━━━━━━━━  43.7kB pytorch-metric-learning    0.6s
# Extracting       ━━━━━━━━╸━━━━━━━━╸━━━━━       2                            0.1s[+] 0.8s
# Downloading  (3) ━━━━━━━━━━━━━━━━━━━━━━━ 251.0kB pytorch-metric-learning    0.7s
# Extracting       ━━━━━━━━╸━━━━━━━━╸━━━━━       2                            0.1s[+] 0.9s
# Downloading  (3) ━━━━━━━━━━━━━━━━━━━━━━━ 251.0kB scikit-learn               0.8s
# Extracting       ━━━━━━━━╸━━━━━━━━╸━━━━━       2                            0.1s[+] 1.0s
# Downloading  (3) ━━━━━━━━━━━━━━━━━━━━━━━ 251.0kB scikit-learn               0.9s
# Extracting       ━━━━━━━━╸━━━━━━━━╸━━━━━       2                            0.1s[+] 1.1s
# Downloading  (3) ━━━━━━━━━━━━━━━━━━━━━━━ 251.0kB scikit-learn               1.0s
# Extracting       ━━━━━━━━╸━━━━━━━━╸━━━━━       2                            0.1spytorch-metric-learning                             71.4kB @  60.0kB/s  1.2s
# [+] 1.2s
# Downloading  (2) ━━━━━━━━━━━━━━━━━━━━━━━ 299.7kB scikit-learn               1.1s
# Extracting   (1) ━━━━━━━━╸━━━━╸━━━━━━━━━       2 pytorch-metric-learning    0.1s[+] 1.3s
# Downloading  (2) ━━━━━━━━━━━━━━━━━━━━━━━ 299.7kB openssl                    1.2s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 1.4s
# Downloading  (2) ━━━━━━━━━━━━━━━━━━━━━━━ 454.1kB openssl                    1.3s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 1.5s
# Downloading  (2) ╸━━━━━━━━━━━━━━━━━━━━━━ 781.8kB openssl                    1.4s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 1.6s
# Downloading  (2) ━╸━━━━━━━━━━━━━━━━━━━━━ 838.3kB openssl                    1.5s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 1.7s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.3MB scikit-learn               1.6s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 1.8s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.4MB scikit-learn               1.7s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 1.9s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.4MB scikit-learn               1.8s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 2.0s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.4MB scikit-learn               1.9s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 2.1s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.4MB openssl                    2.0s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 2.2s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.4MB openssl                    2.1s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 2.3s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.5MB openssl                    2.2s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 2.4s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB openssl                    2.3s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 2.5s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               2.4s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 2.6s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               2.5s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 2.7s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               2.6s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 2.8s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               2.7s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 2.9s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB openssl                    2.8s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 3.0s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB openssl                    2.9s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 3.1s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB openssl                    3.0s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 3.2s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB openssl                    3.1s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 3.3s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               3.2s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 3.4s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               3.3s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 3.5s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               3.4s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 3.6s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               3.5s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 3.7s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB openssl                    3.6s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 3.8s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB openssl                    3.7s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 3.9s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB openssl                    3.8s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 4.0s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB openssl                    3.9s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 4.1s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               4.0s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 4.2s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               4.1s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 4.3s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               4.2s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 4.4s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               4.3s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 4.5s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB openssl                    4.4s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 4.6s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB openssl                    4.5s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 4.7s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB openssl                    4.6s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 4.8s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB openssl                    4.7s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 4.9s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               4.8s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 5.0s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               4.9s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 5.1s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               5.0s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 5.2s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB scikit-learn               5.1s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 5.3s
# Downloading  (2) ━━╸━━━━━━━━━━━━━━━━━━━━   1.6MB openssl                    5.2s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 5.4s
# Downloading  (2) ━━━╸━━━━━━━━━━━━━━━━━━━   1.7MB openssl                    5.3s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 5.5s
# Downloading  (2) ━━━╸━━━━━━━━━━━━━━━━━━━   1.7MB openssl                    5.4s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 5.6s
# Downloading  (2) ━━━╸━━━━━━━━━━━━━━━━━━━   1.7MB openssl                    5.5s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 5.7s
# Downloading  (2) ━━━╸━━━━━━━━━━━━━━━━━━━   1.7MB scikit-learn               5.6s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 5.8s
# Downloading  (2) ━━━╸━━━━━━━━━━━━━━━━━━━   1.7MB scikit-learn               5.7s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 5.9s
# Downloading  (2) ━━━╸━━━━━━━━━━━━━━━━━━━   1.7MB scikit-learn               5.8s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 6.0s
# Downloading  (2) ━━━╸━━━━━━━━━━━━━━━━━━━   2.0MB scikit-learn               5.9s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 6.1s
# Downloading  (2) ━━━╸━━━━━━━━━━━━━━━━━━━   2.0MB openssl                    6.0s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 6.2s
# Downloading  (2) ━━━╸━━━━━━━━━━━━━━━━━━━   2.0MB openssl                    6.1s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 6.3s
# Downloading  (2) ━━━━╸━━━━━━━━━━━━━━━━━━   2.1MB openssl                    6.2s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 6.4s
# Downloading  (2) ━━━━╸━━━━━━━━━━━━━━━━━━   2.2MB openssl                    6.3s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 6.5s
# Downloading  (2) ━━━━╸━━━━━━━━━━━━━━━━━━   2.4MB scikit-learn               6.4s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 6.6s
# Downloading  (2) ━━━━╸━━━━━━━━━━━━━━━━━━   2.4MB scikit-learn               6.5s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 6.7s
# Downloading  (2) ━━━━╸━━━━━━━━━━━━━━━━━━   2.4MB scikit-learn               6.6s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 6.8s
# Downloading  (2) ━━━━╸━━━━━━━━━━━━━━━━━━   2.4MB scikit-learn               6.7s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 6.9s
# Downloading  (2) ━━━━━╸━━━━━━━━━━━━━━━━━   2.6MB openssl                    6.8s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 7.0s
# Downloading  (2) ━━━━━╸━━━━━━━━━━━━━━━━━   2.6MB openssl                    6.9s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 7.1s
# Downloading  (2) ━━━━━╸━━━━━━━━━━━━━━━━━   2.7MB openssl                    7.0s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 7.2s
# Downloading  (2) ━━━━━╸━━━━━━━━━━━━━━━━━   2.7MB openssl                    7.1s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 7.3s
# Downloading  (2) ━━━━━╸━━━━━━━━━━━━━━━━━   2.7MB scikit-learn               7.2s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 7.4s
# Downloading  (2) ━━━━━━╸━━━━━━━━━━━━━━━━   2.9MB scikit-learn               7.3s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 7.5s
# Downloading  (2) ━━━━━━╸━━━━━━━━━━━━━━━━   3.0MB scikit-learn               7.4s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 7.6s
# Downloading  (2) ━━━━━━╸━━━━━━━━━━━━━━━━   3.1MB scikit-learn               7.5s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 7.7s
# Downloading  (2) ━━━━━━╸━━━━━━━━━━━━━━━━   3.1MB openssl                    7.6s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 7.8s
# Downloading  (2) ━━━━━━╸━━━━━━━━━━━━━━━━   3.1MB openssl                    7.7s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2s[+] 7.9s
# Downloading  (2) ━━━━━━━╸━━━━━━━━━━━━━━━   3.5MB openssl                    7.8s
# Extracting       ━━━━━━━━━━━━╸━━━━━━━━━━       3                            0.2sopenssl                                              2.1MB @ 268.9kB/s  7.9s
# [+] 8.0s
# Downloading  (1) ━━━━━━━━╸━━━━━━━━━━━━━━   3.7MB scikit-learn               7.9s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 8.1s
# Downloading  (1) ━━━━━━━━╸━━━━━━━━━━━━━━   3.8MB scikit-learn               8.0s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 8.2s
# Downloading  (1) ━━━━━━━━╸━━━━━━━━━━━━━━   3.8MB scikit-learn               8.1s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 8.3s
# Downloading  (1) ━━━━━━━━╸━━━━━━━━━━━━━━   3.8MB scikit-learn               8.2s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 8.4s
# Downloading  (1) ━━━━━━━━╸━━━━━━━━━━━━━━   3.9MB scikit-learn               8.3s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 8.5s
# Downloading  (1) ━━━━━━━━━╸━━━━━━━━━━━━━   4.1MB scikit-learn               8.4s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 8.6s
# Downloading  (1) ━━━━━━━━━╸━━━━━━━━━━━━━   4.3MB scikit-learn               8.5s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 8.7s
# Downloading  (1) ━━━━━━━━━╸━━━━━━━━━━━━━   4.3MB scikit-learn               8.6s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 8.8s
# Downloading  (1) ━━━━━━━━━╸━━━━━━━━━━━━━   4.4MB scikit-learn               8.7s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 8.9s
# Downloading  (1) ━━━━━━━━━━╸━━━━━━━━━━━━   4.6MB scikit-learn               8.8s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 9.0s
# Downloading  (1) ━━━━━━━━━━━╸━━━━━━━━━━━   4.9MB scikit-learn               8.9s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 9.1s
# Downloading  (1) ━━━━━━━━━━━╸━━━━━━━━━━━   5.0MB scikit-learn               9.0s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 9.2s
# Downloading  (1) ━━━━━━━━━━━╸━━━━━━━━━━━   5.0MB scikit-learn               9.1s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 9.3s
# Downloading  (1) ━━━━━━━━━━━╸━━━━━━━━━━━   5.0MB scikit-learn               9.2s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 9.4s
# Downloading  (1) ━━━━━━━━━━━━╸━━━━━━━━━━   5.4MB scikit-learn               9.3s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 9.5s
# Downloading  (1) ━━━━━━━━━━━━╸━━━━━━━━━━   5.6MB scikit-learn               9.4s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 9.6s
# Downloading  (1) ━━━━━━━━━━━━━╸━━━━━━━━━   5.8MB scikit-learn               9.5s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 9.7s
# Downloading  (1) ━━━━━━━━━━━━━━╸━━━━━━━━   6.2MB scikit-learn               9.6s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 9.8s
# Downloading  (1) ━━━━━━━━━━━━━━╸━━━━━━━━   6.2MB scikit-learn               9.7s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 9.9s
# Downloading  (1) ━━━━━━━━━━━━━━╸━━━━━━━━   6.4MB scikit-learn               9.8s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 10.0s
# Downloading  (1) ━━━━━━━━━━━━━━━╸━━━━━━━   6.5MB scikit-learn               9.9s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 10.1s
# Downloading  (1) ━━━━━━━━━━━━━━━━╸━━━━━━   6.9MB scikit-learn              10.0s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 10.2s
# Downloading  (1) ━━━━━━━━━━━━━━━━━╸━━━━━   7.4MB scikit-learn              10.1s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 10.3s
# Downloading  (1) ━━━━━━━━━━━━━━━━━╸━━━━━   7.4MB scikit-learn              10.2s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 10.4s
# Downloading  (1) ━━━━━━━━━━━━━━━━━╸━━━━━   7.4MB scikit-learn              10.3s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 10.5s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━╸━━━━   7.7MB scikit-learn              10.4s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 10.6s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━╸━━━   8.1MB scikit-learn              10.5s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 10.7s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━╸━━   8.7MB scikit-learn              10.6s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 10.8s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━╸━━   8.8MB scikit-learn              10.7s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2s[+] 10.9s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━╸━━   8.8MB scikit-learn              10.8s
# Extracting       ━━━━━━━━━━━━━━━━━╸━━━━━       4                            0.2sscikit-learn                                         7.0MB @ 641.1kB/s 10.9s
# [+] 11.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   9.2MB                           10.9s
# Extracting   (1) ━━━━━━━━━━━━━━━━━╸━━━━━       4 scikit-learn               0.2s[+] 11.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   9.2MB                           10.9s
# Extracting   (1) ━━━━━━━━━━━━━━━━━╸━━━━━       4 scikit-learn               0.3s[+] 11.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   9.2MB                           10.9s
# Extracting   (1) ━━━━━━━━━━━━━━━━━╸━━━━━       4 scikit-learn               0.4sPreparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import pytorch_metric_learning
import pytorch_metric_learning.utils.logging_presets as logging_presets
from pytorch_metric_learning import losses, miners, samplers, testers, trainers
from pytorch_metric_learning.utils.accuracy_calculator import AccuracyCalculator
import umap

# %%
record_keeper, _, _ = logging_presets.get_record_keeper(
    "contrastive_resnet_logs", "example_tensorboard"
)
hooks = logging_presets.get_hook_container(record_keeper)
dataset_dict = {"val": CelebAPositives(
    root='/home/anspiridonov/TopologicalRegularization/data/celeba',
    split='valid',
    target_type=['augmented positives 1'],
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
    ]),
)}
model_folder = "example_saved_models"


def visualizer_hook(umapper, umap_embeddings, labels, split_name, keyname, *args):
    logging.info(
        "UMAP plot for the {} split and label set {}".format(split_name, keyname)
    )
    label_set = np.unique(labels)
    num_classes = len(label_set)
    plt.figure(figsize=(20, 15))
    plt.gca().set_prop_cycle(
        cycler(
            "color", [plt.cm.nipy_spectral(i) for i in np.linspace(0, 0.9, num_classes)]
        )
    )
    for i in range(num_classes):
        idx = labels == label_set[i]
        plt.plot(umap_embeddings[idx, 0], umap_embeddings[idx, 1], ".", markersize=1)
    plt.show()


# Create the tester
tester = testers.GlobalEmbeddingSpaceTester(
    end_of_testing_hook=hooks.end_of_testing_hook,
    visualizer=umap.UMAP(),
    visualizer_hook=visualizer_hook,
    dataloader_num_workers=2,
    accuracy_calculator=AccuracyCalculator(k="max_bin_count"),
)

end_of_epoch_hook = hooks.end_of_epoch_hook(
    tester, dataset_dict, model_folder, test_interval=1, patience=1
)

# %% [markdown]
# ### just metric learning

# %% [markdown]
# #### augmantation-based metric learning

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set trunk model and replace the softmax layer with an identity function
trunk = torchvision.models.resnet18(pretrained=True)
trunk_output_size = trunk.fc.in_features
trunk.fc = nn.Identity()
trunk = trunk.to(device)

# Set embedder model. This takes in the output of the trunk and outputs 64 dimensional embeddings
embedder = MLP([trunk_output_size, 64]).to(device)

# Set optimizers
trunk_optimizer = torch.optim.AdamW(trunk.parameters(), lr=0.00001, weight_decay=0.0001)
embedder_optimizer = torch.optim.AdamW(
    embedder.parameters(), lr=0.0001, weight_decay=0.0001
)

# %% [markdown]
# ### metric learning with classifier

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set trunk model and replace the softmax layer with an identity function
trunk = torchvision.models.resnet18(pretrained=True)
trunk_output_size = trunk.fc.in_features
trunk.fc = nn.Identity()
trunk = trunk.to(device)

# Set embedder model. This takes in the output of the trunk and outputs 64 dimensional embeddings
embedder = MLP([trunk_output_size, 64]).to(device)

# Set optimizers
trunk_optimizer = torch.optim.AdamW(trunk.parameters(), lr=0.00001, weight_decay=0.0001)
embedder_optimizer = torch.optim.AdamW(
    embedder.parameters(), lr=0.0001, weight_decay=0.0001
)

# %%
models = {"trunk": trunk, "embedder": embedder}
optimizers = {
    "trunk_optimizer": trunk_optimizer,
    "embedder_optimizer": embedder_optimizer,
}
loss = losses.TripletMarginLoss(margin=0.1)
loss_funcs = {"metric_loss": loss}

# %%
train_dataset = CelebAPositives(
    root='/home/anspiridonov/TopologicalRegularization/data/celeba',
    split='valid',
    target_type=['augmented positives 1'],
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(0.5),
        transforms.ColorJitter(brightness=0.5, hue=0.3, saturation=0.1),
        transforms.GaussianBlur(kernel_size=5, sigma=(0.01, 0.5)),
        transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.8, 1.0)),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
    ])
)

trainer = trainers.MetricLossOnly(
    models,
    optimizers,
    64,
    loss_funcs,
    train_dataset,
    dataloader_num_workers=2,
    end_of_iteration_hook=hooks.end_of_iteration_hook,
    end_of_epoch_hook=end_of_epoch_hook,
)

# %% [markdown]
# ### just classifier

# %% [markdown]
# ### autoencoder-like pretraining
